# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
df_ratings = pd.read_csv("C:\\Users\\colom\\OneDrive - ITESO\\iteso\\5to semestre\\cienciadatos\\movielens-ven-2024\\data\\ml-latest-small\\ml-latest-small\\ratings.csv")
df_links = pd.read_csv("C:\\Users\\colom\\OneDrive - ITESO\\iteso\\5to semestre\\cienciadatos\\movielens-ven-2024\\data\\ml-latest-small\\ml-latest-small\\links.csv")
df_movies = pd.read_csv("C:\\Users\\colom\\OneDrive - ITESO\\iteso\\5to semestre\\cienciadatos\\movielens-ven-2024\\data\\ml-latest-small\\ml-latest-small\\movies.csv")
df_tags = pd.read_csv("C:\\Users\\colom\\OneDrive - ITESO\\iteso\\5to semestre\\cienciadatos\\movielens-ven-2024\\data\\ml-latest-small\\ml-latest-small\\tags.csv")

# %%
df = pd.merge(df_ratings, df_links, on = 'movieId')
df = pd.merge(df, df_movies, on = 'movieId')
df = pd.merge(df, df_tags, on = 'movieId')
df
# Out:
#         userId_x  movieId  rating  timestamp_x   imdbId    tmdbId  \
# 0              1        1     4.0    964982703   114709     862.0
# 1              1        1     4.0    964982703   114709     862.0
# 2              1        1     4.0    964982703   114709     862.0
# 3              1        3     4.0    964981247   113228   15602.0
# 4              1        3     4.0    964981247   113228   15602.0
# ...          ...      ...     ...          ...      ...       ...
# 233208       610   168252     5.0   1493846352  3315342  263115.0
# 233209       610   168252     5.0   1493846352  3315342  263115.0
# 233210       610   168252     5.0   1493846352  3315342  263115.0
# 233211       610   168252     5.0   1493846352  3315342  263115.0
# 233212       610   168252     5.0   1493846352  3315342  263115.0
#
#                           title                                       genres  \
# 0              Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# ...

# %%
df.dtypes
# Out:
# userId_x         int64
# movieId          int64
# rating         float64
# timestamp_x      int64
# imdbId           int64
# tmdbId         float64
# title           object
# genres          object
# userId_y         int64
# tag             object
# timestamp_y      int64
# dtype: object

# %%
df.describe()
# Out:
#             userId_x        movieId         rating   timestamp_x  \
# count  233213.000000  233213.000000  233213.000000  2.332130e+05
# mean      309.688191   12319.999443       3.966535  1.213524e+09
# std       178.206387   28243.919401       0.968637  2.250448e+08
# min         1.000000       1.000000       0.500000  8.281246e+08
# 25%       156.000000     296.000000       3.500000  1.017365e+09
# 50%       309.000000    1198.000000       4.000000  1.217325e+09
# 75%       460.000000    4638.000000       5.000000  1.443201e+09
# max       610.000000  193565.000000       5.000000  1.537799e+09
#
#              imdbId         tmdbId       userId_y   timestamp_y
# count  2.332130e+05  233213.000000  233213.000000  2.332130e+05
# mean   2.610632e+05    9378.277742     470.683564  1.384774e+09
# std    4.414411e+05   36943.139800     153.329632  1.534621e+08
# min    1.234900e+04      11.000000       2.000000  1.137179e+09
# ...
